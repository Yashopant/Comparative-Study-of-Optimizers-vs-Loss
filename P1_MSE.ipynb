# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv('HW.csv')

# %%
data.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
data=data.drop('Index',axis=1)

# %%
data.head()
# Out:
#    Height(Inches)  Weight(Pounds)
# 0        65.78331        112.9925
# 1        71.51521        136.4873
# 2        69.39874        153.0269
# 3        68.21660        142.3354
# 4        67.78781        144.2971

# %%
data.shape
# Out:
# (25000, 2)

# %%
data.describe()
# Out:
#        Height(Inches)  Weight(Pounds)
# count    25000.000000    25000.000000
# mean        67.993114      127.079421
# std          1.901679       11.660898
# min         60.278360       78.014760
# 25%         66.704397      119.308675
# 50%         67.995700      127.157750
# 75%         69.272958      134.892850
# max         75.152800      170.924000

# %%
import matplotlib.pyplot as plt


plt.hist(data['Height(Inches)'], bins=30, edgecolor='black')
plt.title('Histogram of Height')
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(data['Weight(Pounds)'], bins=30, edgecolor='black')
plt.title('Histogram of Weight')
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.show()

# %%
data.corr()
# Out:
#                 Height(Inches)  Weight(Pounds)
# Height(Inches)        1.000000        0.502859
# Weight(Pounds)        0.502859        1.000000

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
data_scaled=scaler.fit_transform(data)

# %%
data_scaled=pd.DataFrame(data_scaled)

# %%
data_scaled
# Out:
#               0         1
# 0      0.370095  0.376472
# 1      0.755447  0.629351
# 2      0.613158  0.807370
# 3      0.533683  0.692295
# 4      0.504856  0.713410
# ...         ...       ...
# 24995  0.620110  0.430705
# 24996  0.287063  0.453975
# 24997  0.297167  0.433226
# 24998  0.487468  0.583940
# 24999  0.578123  0.504357
#
# [25000 rows x 2 columns]

# %%
import tensorflow as tf
model_ADAM = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(units=1)
])
# Out:
# WARNING:tensorflow:From C:\Users\dell\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\dell\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
model_ADAM.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From C:\Users\dell\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model_ADAM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Sample data
x_data = np.array(data_scaled[0])
y_data = np.array(data_scaled[1])

# Function to calculate squared loss
def squared_loss(m, b, x, y):
    predictions = m * x + b
    loss = 0.5 * np.mean((predictions - y)**2)
    return loss

# Generate 3D data for slope (m) and y-intercept (b)
m_values = np.linspace(-2, 2, 100)
b_values = np.linspace(-2, 2, 100)
m_values, b_values = np.meshgrid(m_values, b_values)

# Calculate squared loss for each combination of m and b
loss_values = np.zeros_like(m_values)  # Initialize the loss array

for i in range(m_values.shape[0]):
    for j in range(m_values.shape[1]):
        loss_values[i, j] = squared_loss(m_values[i, j], b_values[i, j], x_data, y_data)

# Plot 3D graph
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(m_values, b_values, loss_values, cmap='viridis', alpha=0.8)
ax.set_xlabel('Slope (m)')
ax.set_ylabel('Y-Intercept (b)')
ax.set_zlabel('Squared Loss')
ax.set_title('3D Plot of Slope-Intercept and Squared Loss')

plt.show()

# %%
history_ADAM= model_ADAM.fit(data_scaled[0],data_scaled[1], epochs=20)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\dell\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 782/782 [==============================] - 3s 2ms/step - loss: 0.2266
# Epoch 2/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0179
# Epoch 3/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0158
# Epoch 4/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0150
# Epoch 5/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0141
# Epoch 6/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0133
# Epoch 7/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0126
# Epoch 8/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0121
# Epoch 9/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0119
# Epoch 10/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 11/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 12/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 13/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 14/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 15/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 16/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 17/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 18/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 19/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 20/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118

# %%
weights, bias = model_ADAM.get_weights()
print("Trained Weights:", weights)
print("Trained Bias:", bias)
# Out:
# Trained Weights: [[0.49160025]]
# Trained Bias: [0.26942423]

# %%
model_rmsprop = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(units=1)
])

# %%
model_rmsprop.compile(optimizer='rmsprop', loss='mean_squared_error')

# %%
history_rmsprop= model_rmsprop.fit(data_scaled[0],data_scaled[1], epochs=20)
# Out:
# Epoch 1/20
# 782/782 [==============================] - 3s 2ms/step - loss: 0.7290
# Epoch 2/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0312
# Epoch 3/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0182
# Epoch 4/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0136
# Epoch 5/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0122
# Epoch 6/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0119
# Epoch 7/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 8/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 9/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 10/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 11/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 12/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 13/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 14/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 15/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 16/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 17/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0118
# Epoch 18/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 19/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 20/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118

# %%
weights, bias = model_rmsprop.get_weights()
print("Trained Weights:", weights)
print("Trained Bias:", bias)
# Out:
# Trained Weights: [[0.49384025]]
# Trained Bias: [0.2727344]

# %%
model_SGD = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(units=1)
])

# %%
model_SGD.compile(optimizer='SGD', loss='mean_squared_error')

# %%
history_SGD= model_SGD.fit(data_scaled[0],data_scaled[1], epochs=20)
# Out:
# Epoch 1/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0474
# Epoch 2/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0195
# Epoch 3/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0169
# Epoch 4/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0152
# Epoch 5/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0141
# Epoch 6/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0133
# Epoch 7/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0128
# Epoch 8/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0125
# Epoch 9/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0122
# Epoch 10/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0121
# Epoch 11/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0120
# Epoch 12/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0119
# Epoch 13/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0119
# Epoch 14/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 15/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 16/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 17/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 18/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 19/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118
# Epoch 20/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0118

# %%
weights, bias = model_SGD.get_weights()
print("Trained Weights:", weights)
print("Trained Bias:", bias)
# Out:
# Trained Weights: [[0.4765861]]
# Trained Bias: [0.28049317]

# %%
model_Adagrad = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(units=1)
])

# %%
model_Adagrad.compile(optimizer='Adagrad', loss='mean_squared_error')

# %%
history_Adagrad= model_Adagrad.fit(data_scaled[0],data_scaled[1], epochs=20)
# Out:
# Epoch 1/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0434
# Epoch 2/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0307
# Epoch 3/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0249
# Epoch 4/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0213
# Epoch 5/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0190
# Epoch 6/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0173
# Epoch 7/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0161
# Epoch 8/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0152
# Epoch 9/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0146
# Epoch 10/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0141
# Epoch 11/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0138
# Epoch 12/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0135
# Epoch 13/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0133
# Epoch 14/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0131
# Epoch 15/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0130
# Epoch 16/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0129
# Epoch 17/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0129
# Epoch 18/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0128
# Epoch 19/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0128
# Epoch 20/20
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0127

# %%
weights, bias = model_Adagrad.get_weights()
print("Trained Weights:", weights)
print("Trained Bias:", bias)
# Out:
# Trained Weights: [[0.71654254]]
# Trained Bias: [0.14475203]

# %%
model_Adadelta = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(units=1)
])

# %%
model_Adadelta.compile(optimizer='Adadelta', loss='mean_squared_error')

# %%
history_Adadelta= model_Adadelta.fit(data_scaled[0],data_scaled[1], epochs=20)
# Out:
# Epoch 1/20
# 782/782 [==============================] - 3s 2ms/step - loss: 1.2684
# Epoch 2/20
# 782/782 [==============================] - 2s 2ms/step - loss: 1.2619
# Epoch 3/20
# 782/782 [==============================] - 2s 2ms/step - loss: 1.2537
# Epoch 4/20
# 782/782 [==============================] - 2s 2ms/step - loss: 1.2442
# Epoch 5/20
# 782/782 [==============================] - 2s 2ms/step - loss: 1.2335
# Epoch 6/20
# 782/782 [==============================] - 2s 2ms/step - loss: 1.2218
# Epoch 7/20
# 782/782 [==============================] - 2s 2ms/step - loss: 1.2092
# Epoch 8/20
# 782/782 [==============================] - 2s 2ms/step - loss: 1.1959
# Epoch 9/20
# 782/782 [==============================] - 2s 2ms/step - loss: 1.1820
# Epoch 10/20
# 782/782 [==============================] - 2s 2ms/step - loss: 1.1675
# Epoch 11/20
# 782/782 [==============================] - 2s 3ms/step - loss: 1.1525
# Epoch 12/20
# 782/782 [==============================] - 2s 3ms/step - loss: 1.1370
# Epoch 13/20
# 782/782 [==============================] - 2s 3ms/step - loss: 1.1212
# Epoch 14/20
# 782/782 [==============================] - 2s 2ms/step - loss: 1.1049
# Epoch 15/20
# 782/782 [==============================] - 2s 2ms/step - loss: 1.0884
# Epoch 16/20
# 782/782 [==============================] - 2s 3ms/step - loss: 1.0716
# Epoch 17/20
# 782/782 [==============================] - 2s 3ms/step - loss: 1.0545
# Epoch 18/20
# 782/782 [==============================] - 2s 2ms/step - loss: 1.0373
# Epoch 19/20
# 782/782 [==============================] - 2s 3ms/step - loss: 1.0199
# Epoch 20/20
# 782/782 [==============================] - 2s 3ms/step - loss: 1.0023

# %%
weights, bias = model_Adadelta.get_weights()
print("Trained Weights:", weights)
print("Trained Bias:", bias)
# Out:
# Trained Weights: [[-1.0272906]]
# Trained Bias: [0.08933679]

# %%
training_histories = [history_ADAM,history_rmsprop,history_SGD,history_Adagrad,history_Adadelta]

# %%
optimizers_list=['ADAM','rmsprop','SGD','Adagrad','Adadelta']

# %%
plt.figure(figsize=(12, 8))
for i, history in enumerate(training_histories):
    plt.plot(history.history['loss'], label=f'Model {i + 1} - {optimizers_list[i]}')

plt.title('Training Loss of Different Models with Different Optimizers')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Sample data
x_data = np.array(data_scaled[0])
y_data = np.array(data_scaled[1])

# Function to calculate absolute loss
def absolute_loss(m, b, x, y):
    predictions = m * x + b
    loss = np.mean(np.abs(predictions - y))  # Calculate mean absolute error
    return loss

# Generate 3D data for slope (m) and y-intercept (b)
m_values = np.linspace(-2, 2, 100)
b_values = np.linspace(-2, 2, 100)
m_values, b_values = np.meshgrid(m_values, b_values)

# Calculate absolute loss for each combination of m and b
loss_values = np.zeros_like(m_values)

for i in range(m_values.shape[0]):
    for j in range(m_values.shape[1]):
        loss_values[i, j] = absolute_loss(m_values[i, j], b_values[i, j], x_data, y_data)

# Plot 3D graph
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(m_values, b_values, loss_values, cmap='viridis', alpha=0.8)
ax.set_xlabel('Slope (m)')
ax.set_ylabel('Y-Intercept (b)')
ax.set_zlabel('Mean Absolute Error')
ax.set_title('3D Plot of Slope-Intercept and Mean Absolute Error')

plt.show()
